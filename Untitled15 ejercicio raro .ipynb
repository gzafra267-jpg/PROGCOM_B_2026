# %% [markdown]
# <a href="https://colab.research.google.com/github/gzafra267-jpg/PROGCOM_B_2026/blob/main/Untitled15%20ejercicio%20raro%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color_techo="cafe"
color_pared="cafe"
cant_ventanas=4
cant_puertas=2
cant_pisos=1
cant_baños=2
color_marco_ventanas="blanco"
decoracion_flores=True
letrero=False
graffiti=False
nombre_letrero="No le puse"

# %%
def decorando_floristeria(a,b,c,d,e,f,g,h,letrero,graffiti):
  color_techo=a
  color_pared=b
  cant_ventanas=c
  cant_puertas=d
  cant_pisos=e
  cant_baños=f
  color_marco_ventanas=g
  if h: flores_decoracion=input ("Ingrese las flores con las que decoró el lugar ")
  if letrero: nombre_letrero=input("¿Cuál es el nombre de la floristería?")
  if graffiti: dibujo_graffiti= input("Qué dibujo pintaste")
  print(f"el color de mi pared es {b}, tengo {c},\n cantidad de ventanas, \n tiene {d} cantidad de puertas, \n tiene {e} cantidad de pisos, \n el color del techo es {a}, \n tiene {f}cantidad de baños, \n el color del marcos de la ventana es{g}, {nombre_letrero}, la decoración de flores {flores_decoracion}, y {graffiti}")

# %%
decorando_floristeria("cafe","cafe",4, 2, 1,2,"blanco",True,False,False)
# Out:
# Ingrese las flores con las que decoró el lugar ssana
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_1438/3485767604.py in <cell line: 0>()
# ----> 1 decorando_floristeria("cafe","cafe",4, 2, 1,2,"blanco",True,False,False)
#
# /tmp/ipykernel_1438/1624858324.py in decorando_floristeria(a, b, c, d, e, f, g, h, letrero, graffiti)
#      10   if letrero: nombre_letrero=input("¿Cuál es el nombre de la floristería?")
#      11   if graffiti: dibujo_graffiti= input("Qué dibujo pintaste")
# ---> 12   print(f"el color de mi pared es {b}, tengo {c},\n cantidad de ventanas, \n tiene {d} cantidad de puertas, \n tiene {e} cantidad de pisos, \n el color del techo es {a}, \n tiene {f}cantidad de baños, \n el color del marcos de la ventana es{g}, {nombre_letrero}, la decoración de flores {flores_decoracion}, y {graffiti}")
#      13
#
# ...
