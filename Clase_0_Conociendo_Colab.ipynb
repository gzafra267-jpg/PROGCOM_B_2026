# %% [markdown]
# <a href="https://colab.research.google.com/github/gzafra267-jpg/PROGCOM_B_2026/blob/main/Clase_0_Conociendo_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titulo nivel 1
# ##Titulo de nivel 2
# ### Titulo de nivel 3
#
# hola como estas? 😂😊❤️

# %% [markdown]
# #Saludando al mundo

# %%
print("hola mundo")
nombre = input(" Cómo te llamas? ")
nombre
# Out:
# hola mundo
#  Cómo te llamas? gabriela
# 'gabriela '

# %%
edad1 =int(input("cauntos años tienes? "))
edad2=int(input("paula, cuantos años tiene tu compañera ? "))
print(f"suma de las dos edades es {edad1+edad2}")
# Out:
# cauntos años tienes? 18
# paula, cuantos años tiene tu compañera ? 20
# suma de las dos edades es 38

# %% [markdown]
# ##La suma de ambas de ambas edad es:
