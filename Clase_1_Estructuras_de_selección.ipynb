# %% [markdown]
# <a href="https://colab.research.google.com/github/gzafra267-jpg/PROGCOM_B_2026/blob/main/Clase_1_Estructuras_de_selecci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Estructuras de seleción
# evalua condiciones(su valor de verdad)
#
# 1) IF / ELSE
# 2) IF / TERNARIO
# 3) IF / ELIFE/ ELSE
# 4) CASE

# %% [markdown]
# 1) IF / ELSE
# Evalúa una o más condiciones y dependiendo de su valor de verdad, realizará una acción u otra ( solo dos acciones )
#
# SINTAXIS
#
# IF (condición) :
# si la condicion es verdadera, se ejecuta este pedazo de codigo
# ElSE:
# si la condición es falsa, se ejecuta este pedazo de codigo.

# %%
lluvia=input("Esta lloviendo?")

if lluvia=="sí" or lluvia=="si" or lluvia=="si, muchisimo":
 print("use sombrella, recoja la ropa. ")
else:
 print("salga tranquilo")
# Out:
# Esta lloviendo? no
# salga tranquilo

# %% [markdown]
# ## if ternario
# SINTAXIS
# variable = (codigo si condición es verdadera)
# if (condición) else ( codigo si condición es falsa )

# %%
aguacero = " Use sombreilla, guarde la ropa" if lluvia== "si" else "salga tranquilo"
print(aguacero)
# Out:
# salga tranquilo

# %% [markdown]
# ##3. IF/ELIF/ELSE
# Selecciona entre múltiples respuestas
# Sintaxis
#
# If (condición1):
#   Se ejecuta código si condición1 es verdadera
# elif(condición2):
#   Se ejecuta código si concición2 es verdadera
# elif (condición3):
#   Se ejecuta código si condición3 es verdadera
# .
# .
# .
# elif(condición):
#  Se ejecuta código si condición es verdadera
# else:
#  Se ejecuta código si ninguna de las condiciones anteriores es verdadera

# %%
lluvia= input("Está lloviendo?.Escriba 1 para si y 2 para no: ")
if lluvia==2:
  print("salga tranquilo")
else:
  cantidad= int(input("En que porcentaje 0- muy poco, > 90, torrecial"))
  if  cantidad>= 0 and cantidad<30: print("Esta serenando lleve paraguas")
  elif cantidad >=30 and cantidad<70:
    print("Está lloviendo fuerte. Use sombrilla.Guarde la ropa")
  else:
    print("hay tormenta. No salga de la casa")
# Out:
# Está lloviendo?.Escriba 1 para si y 2 para no1
# En que porcentaje 0- muy poco, > 90, torrecial90
# hay tormenta. No salga de la casa
