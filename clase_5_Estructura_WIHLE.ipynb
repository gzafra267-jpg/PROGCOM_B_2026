# %% [markdown]
# <a href="https://colab.research.google.com/github/gzafra267-jpg/PROGCOM_B_2026/blob/main/clase_5_Estructura_WIHLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #WHILE
# 1. Cuando no se sabe cuantás veces se repite una acción
# 2. Es gobernado por una condición de parada
# 3. Es necesaria una condición inicia, la cúal **DEBE** cambiar adentr del ciclo
#
# Sintaxis
# ´´´´´´´´´´´´´´
#
# while (condición)
# codigo a repetir
# modificación de condición
#
#
# ´
# **OJO**
# La modificación de la condición puede darse de diferetes formas:
# 1. contador
# 2. un acumulador
# 3. Cambio de bandera ( trabajando con booleanos)
# 4. con input.

# %%
#Suponer que la cantidad máxima de votantes son 10
#Suponer que son 5 candidatos
v1=0
v2=0
v3=0
v4=0
v5=0
vn=0
vb=0
votico="s"
persona=0
while votico=="s" and persona<=10:
  id=input("Ingrese su CC: ")
  voto=input("Ingrese su por quién quiere votar:\n1.Elefante blanco\n2.Pantera Rosa\n3.Jp\n4.Paloma\n5.Quevedito\n6.Voto en blanco \n")
  if voto=="1": v1+=1
  elif voto=="2": v2+=1
  elif voto=="3": v3+=1
  elif voto=="4": v4+=1
  elif voto=="5": v5+=1
  elif voto=="6": vb+=1
  else: vn+=1
  persona+=1
  print(f"Gracias por su voto. Van votando {persona} personas.\n")
  votico=input("Hay personas antes de las 4pm ")
  print("")
print(f"Resultados:\nElefante Blanco:{v1}\nPantera Rosa:{v2}\nJP: {v3}\nPaloma: {v4}\nQuevedito: {v4}\nVoto Nulo:{vn}")
# Out:
# Ingrese su CC: 7845123
# Ingrese su por quién quiere votar:
# 1.Elefante blanco
# 2.Pantera Rosa
# 3.Jp
# 4.Paloma
# 5.Quevedito
# 6.Voto en blanco
# 2
# Gracias por su voto. Van votando 1 personas.
#
# Hay personas antes de las 4pm no
#
# Resultados:
# Elefante Blanco:0
# Pantera Rosa:1
# JP: 0
# Paloma: 0
# Quevedito: 0
# Voto Nulo:0

# %% [markdown]
# #Listas
# 1.Tienen index(númeración)
#
# 2. Son finitas
#
# 3. Son mutables
#
# **sintaxis**
#
# #Forma canónica
# variable=[]
# #extención
# variable=[e,e1,e2,e3,....en]
# #comprensión: fórmula que genera todos los elementos de la lista

# %%
figura=["angelito","estrella fugaz", "dinosaurios","diablitos"]
cantidad=[4,2,5,3]

# %% [markdown]
# ##oPERACIONES CON LISTAS
# 1. Recorrer listas
# 2. Verificar dentro de la lista
# 3. Borrar elementos en la lista
# 4. Agregar elemnentos a la lista
# 5. Mutabilidad de las listas

# %% [markdown]
# 1. RECORRER LISTAS

# %%
#len: Calcula el tamaño de un dato
for elemento in range(len(figura)):
  print(figura[elemento])
# Out:
# angelito
# estrella fugaz
# dinosaurios
# diablitos

# %%
for elemento in range (len(figura)):
  print(figura[elemento],":", cantidad[elemento])
# Out:
# angelito : 4
# estrella fugaz : 2
# dinosaurios : 5
# diablitos : 3

# %%
for elemento in figura:
  print(elemento)
# Out:
# angelito
# estrella fugaz
# dinosaurios
# diablitos

# %% [markdown]
# #### 2VERIFICAR ELEMENTOS DENTRO DE LA LISTA
# for elemento in range

# %%
user=input("Que figura de galleta quiere comprar?")
for elemento in range(len(figura)):
  if user==figura[elemento]:
    print("Si hay galleta")
  else: print("no hay galleta")
# Out:
# Que figura de galleta quiere comprar?5
# no hay galleta
# no hay galleta
# no hay galleta
# no hay galleta
# no hay galleta
# no hay galleta

# %%
if user in figura: print("Si hay galleta")
else: print("No hay galleta ")
# Out:
# No hay galleta

# %%
print("Si hay galleta" if user in figura else "no hay galleta")
# Out:
# no hay galleta

# %%
figura [3]="moñitos"
# el .append() es para aumentar el tamaño de la lista
figura.append("dinosaurios")
figura
figura[1:4]
figura[-1]
figura
# Out:
# ['angelito',
#  'estrella fugaz',
#  'dinosaurios',
#  'moñitos',
#  'dinosaurios',
#  'dinosaurios']

# %%
#Imprimir todo hasta la posición 3
figura[:3]
# Out:
# ['angelito', 'estrella fugaz', 'dinosaurios']

# %%
#imprimir desde la posición 1 hasta el final
figura [1:]
# Out:
# ['estrella fugaz', 'dinosaurios', 'moñitos', 'dinosaurios', 'dinosaurios']

# %%
#AQUI ESTAS DICIENDO QUE HAY DESPUES DE LA ULTIMA POSICIÓN DE LA LISTA Y DESPUES DE LA LISTA NO HAY NADA
figura[-1:-3]
# Out:
# []

# %% [markdown]
# ##Metodos de listas
# 1. Append. agrega un elemento a la lista. Aumental el tamaño de la lsita. OJO:
# Diferente a reescribir un elemnto de la lista.
#
# 2. len: calcula el tamaño el tamaño de los datos.
#
# 3. count: cuenta cuántos elementos iguales hay en una lista.
#
# 4. copy: copia los elementos de una lista.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
figura.append("gatitos ")
figura
# Out:
# ['angelito',
#  'estrella fugaz',
#  'dinosaurios',
#  'moñitos',
#  'dinosaurios',
#  'dinosaurios',
#  'gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'gatitos ']

# %%
len(figura)
# Out:
# 9

# %%
figura.count("angelitos")
# Out:
# 0

# %%
galletas=figura.copy()

# %%
galletas
# Out:
# ['angelito',
#  'estrella fugaz',
#  'dinosaurios',
#  'moñitos',
#  'dinosaurios',
#  'dinosaurios',
#  'gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'gatitos ']

# %%
galletas.append("chocolate")

# %%
galletas.index("dinosaurios")
# Out:
# 2

# %%
galletas.reverse()

# %%
galletas
# Out:
# ['gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'dinosaurios',
#  'dinosaurios',
#  'moñitos',
#  'dinosaurios',
#  'estrella fugaz',
#  'angelito']

# %%
galletas.remove("dinosaurios")
galletas
# Out:
# ['gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'moñitos',
#  'estrella fugaz',
#  'angelito']

# %%
galletas.pop(3)
# Out:
# 'moñitos'

# %%
galletas
# Out:
# ['gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'moñitos',
#  'moñitos',
#  'moñitos',
#  'estrella fugaz',
#  'angelito']

# %%
galletas.insert(3,"moñitos")

# %%
galletas
# Out:
# ['gatitos ',
#  'gatitos ',
#  'gatitos ',
#  'moñitos',
#  'moñitos',
#  'moñitos',
#  'moñitos',
#  'moñitos',
#  'moñitos',
#  'moñitos',
#  'estrella fugaz',
#  'angelito']
