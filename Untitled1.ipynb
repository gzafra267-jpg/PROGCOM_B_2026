# %% [markdown]
# <a href="https://colab.research.google.com/github/gzafra267-jpg/PROGCOM_B_2026/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base= int(input("ingreseel valor de la base del trinagulo: "))
altura = int(input("ingrese la altura del triangulo"))
area = (base*altura)/2
print("El área del triangulo es: ", area)

# %%
cel = float(input("ingrese los grados celsius que desea convertir: "))
fah =((cel *(9/5)) + 32)
print("La conversión a Fahrentheit es: ", fah)

# %%
num1 = float(input("ingrese su primer número: "))
num2 = float(input("ingrese su segundo número : "))
num3 = float}(input("ingrese su tercer numero : "))
promedio = (num1 + num2+ num3 )/3
print("El promedio de los tres números ingresados es: ", promedio)
# Out:
# ingrese su primer número: 5
# ingrese su segundo número : 4
# ingrese su tercer numero : 8.2
# El promedio de los tres números ingresados es:  5.733333333333333

# %%
radio = int(input("ingrese el radio del circulo: "))
area = (radio*radio) * 3.1415
perimetro = (2*3.1415*radio)
print ("El area del circulo según su radio es: ", area )
print ("El area del circulo según su perimetro es: ", perimetro )
# Out:
# ingrese el radio del circulo: 5
# El area del circulo según su radio es:  78.53750000000001
# El area del circulo según su perimetro es:  31.415000000000003

# %%
a = float(input("ingrese el valor de a: "))
b = float(input("ingrese el valor de b : "))
c = float(input("ingrese el valor de c : "))
ecuacion1 = (-b +((b*b)- 4*a*c)**1/2)/2*a
ecuacion2 = (-b -((b*b)- 4*a*c)**1/2)/2*a
print ("la primera salución de la expresión cuadratica es: ", ecuacion1)
print ("la segunda salución de la expresión cuadratica es: ", ecuacion2)
# Out:
# ingrese el valor de a: 2
# ingrese el valor de b : 4
# ingrese el valor de c : 12
# la primera salución de la expresión cuadratica es:  -44.0
# la segunda salución de la expresión cuadratica es:  36.0

# %%
num = int(input("ingrese un numero entero culaquiera: "))
if num % 2==0 :
  print("el número es par ")
else:
   print("el número impar  ")
# Out:
# ingrese un numero entero culaquiera: 11
# el número impar par

# %%
num = int(input("ingrese un numero entero culaquiera: "))
print ("el número es impar "  if num % 2==0 else "El numero es impar")
# Out:
# ingrese un numero entero culaquiera: 5
# El numero es impar

# %%
año = float(input("ingrese el año : "))
if (año % 4 == 0 and año 100 !=0) or (año % 400 == 0) :
  print("el año  es bisiesto")
else:
  print ("al año no es bisiesto")
# Out:
#   File "/tmp/ipython-input-491436694.py", line 2
#     if (año % 4 == 0 and año 100 !=0), or (año % 400 == 0) :
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
from os.path import normcase
normcase

# %%
nombre =input("ingrese su nombre: ")
edad = int(input("ingrese su edad: "))
if edad > 70 or edad == 70:
  print(nombre,"es de la tercera edad")
else:
  print("Aún eres joven")
# Out:
# ingrese su nombre: juan
# ingrese su edad: 50
# aún eres joven

# %%
num1 = float(input("ingrese su primer número: "))
num2 = float(input("ingrese su segundo número : "))
num3 = float}(input("ingrese su tercer numero : "))
if (num1 > num2 and num1 >num3 ):
  print(num1, "es el numero mayor")
if num2 > num1 and num2> num3 ):
    print(num2, "es el numero mayor ")
